# %% [markdown]
# Web Design Challenge -- Data page
# ----
#
# #### Note
# * Imported the csv file generated during prior project from Unit 6, in order to export to html without having to rerun all of the code from that project. Rerunning the code would generate a new list of cities, and therefore new plots, so the csv generated from rerunning the code would not match the images already posted on the website's visualization and comparison pages. Importing the csv generated at the time the images were generated will also avoid the alternative of replacing the images already posted to the site after rerunning the code.

# %%
# Dependencies
import pandas as pd
import time

# %%
# Load in file
weather_data = 'C:\\Users\\me\\Desktop\\BBC\\COPY_but-ind-data-pt-06-2020-u-c\\Unit_11_Web\Homework\Resources\\my_cities.csv'

# %%
# Read and display the CSV with Pandas
weather_data_df = pd.read_csv(weather_data)
weather_data_df.head()
# Out:
#                City  Latitude  Longitude  Max Temperature  Humidity  \
# 0         busselton    -33.65     115.33            48.00      70.0
# 1  illoqqortoormiut       NaN        NaN              NaN       NaN
# 2           lagunas     -5.23     -75.68            88.99      55.0
# 3          plouzane     48.38      -4.62            71.60      49.0
# 4             bluff    -46.60     168.33            39.00      83.0
#
#    Cloudiness  Wind Speed Country          Date
# 0         6.0        3.89      AU  1.595518e+09
# 1         NaN         NaN     NaN           NaN
# 2        85.0        2.55      PE  1.595518e+09
# 3        26.0        8.05      FR  1.595519e+09
# 4        83.0        3.00      NZ  1.595518e+09

# %%
# Date conversion
seconds = weather_data_df["Date"]
seconds = time.ctime()
weather_data_df["Date"] = seconds
weather_data_df.head()
# Out:
#                City  Latitude  Longitude  Max Temperature  Humidity  \
# 0         busselton    -33.65     115.33            48.00      70.0
# 1  illoqqortoormiut       NaN        NaN              NaN       NaN
# 2           lagunas     -5.23     -75.68            88.99      55.0
# 3          plouzane     48.38      -4.62            71.60      49.0
# 4             bluff    -46.60     168.33            39.00      83.0
#
#    Cloudiness  Wind Speed Country                      Date
# 0         6.0        3.89      AU  Thu Aug 27 12:06:14 2020
# 1         NaN         NaN     NaN  Thu Aug 27 12:06:14 2020
# 2        85.0        2.55      PE  Thu Aug 27 12:06:14 2020
# 3        26.0        8.05      FR  Thu Aug 27 12:06:14 2020
# 4        83.0        3.00      NZ  Thu Aug 27 12:06:14 2020

# %%
# Drop NAN rows
weather_data_df.dropna()
# Out:
#             City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 0      busselton    -33.65     115.33            48.00      70.0         6.0
# 2        lagunas     -5.23     -75.68            88.99      55.0        85.0
# 3       plouzane     48.38      -4.62            71.60      49.0        26.0
# 4          bluff    -46.60     168.33            39.00      83.0        83.0
# 5       hermanus    -34.42      19.23            66.00      73.0         0.0
# ..           ...       ...        ...              ...       ...         ...
# 617      portree     57.41      -6.19            59.00      88.0        80.0
# 618      dunedin    -45.87     170.50            41.00      73.0        31.0
# 620        buala     -8.14     159.59            81.23      81.0        99.0
# 621  poshekhonye     58.50      39.14            60.75      72.0        66.0
# 623     podujevo     42.91      21.19            86.00      22.0        40.0
#
# ...

# %%
# Convert dataframe into html:
html = weather_data_df.to_html()
html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Max Temperature</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>busselton</td>\n      <td>-33.65</td>\n      <td>115.33</td>\n      <td>48.00</td>\n      <td>70.0</td>\n      <td>6.0</td>\n      <td>3.89</td>\n      <td>AU</td>\n      <td>Thu Aug 27 12:06:14 2020</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>illoqqortoormiut</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>Thu Aug 27 12:06:14 2020</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>lagunas</td>\n      <td>-5.23</td>\n      <td>-75.68</td>\n      <td>88.99</td>\n     
# ...
